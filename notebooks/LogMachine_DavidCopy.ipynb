# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
#import data
data = pd.read_csv("data/ModelData_1.csv")
data.head()
# Out:
#    Servings/s  Calories/s      Fat/s  Sat_Fat/s  Trans_Fat/s  Mono_Fat/s  \
# 0         1.0  100.783428   3.706567   0.478814     0.001744    1.190110
# 1         1.0  347.140000  10.435950   5.186700     0.002800    0.836965
# 2         1.0  186.432627   7.025285   0.571038     0.047022    4.549795
# 3         1.0  137.675750   5.925203   0.385312     0.000000    3.360537
# 4         1.0  198.456000   8.087615   1.228474     0.000420    5.501382
#
#    Poly_Fat/s    Carbs/s   Fiber/s   Sugars/s  ...      B6/s  Folate_eq/s  \
# 0    1.662028  12.935162  2.351610   0.802769  ...  0.108401    91.229498
# 1    1.371930  50.166950  5.145125  11.966875  ...  0.489270   210.806250
# 2    1.417736  27.970713  7.459813   2.474852  ...  0.263017    46.731444
# 3    1.417505  19.815070  3.004800  13.549490  ...  0.199595    73.137500
# 4    0.972848  29.506350  7.253650   4.189283  ...  0.615219   104.624000
#
#    Folate_food/s     B12/s    Vit_D/s   Vit_E/s     Vit_K/s     Water/s  \
# ...

# %%
#
testdata = data[['Calories/s', 'Fat/s', 'Sat_Fat/s', 'Trans_Fat/s', 'Mono_Fat/s', 'Poly_Fat/s',
                'Carbs/s', 'Fiber/s', 'Sugars/s','Protein/s', 'Cholesterol/s', 'Sodium/s', 'Healthy', 'HealthyLabel']].copy()
testdata.head()
# Out:
#    Calories/s      Fat/s  Sat_Fat/s  Trans_Fat/s  Mono_Fat/s  Poly_Fat/s  \
# 0  100.783428   3.706567   0.478814     0.001744    1.190110    1.662028
# 1  347.140000  10.435950   5.186700     0.002800    0.836965    1.371930
# 2  186.432627   7.025285   0.571038     0.047022    4.549795    1.417736
# 3  137.675750   5.925203   0.385312     0.000000    3.360537    1.417505
# 4  198.456000   8.087615   1.228474     0.000420    5.501382    0.972848
#
#      Carbs/s   Fiber/s   Sugars/s  Protein/s  Cholesterol/s    Sodium/s  \
# 0  12.935162  2.351610   0.802769   4.440050          0.000   12.835803
# 1  50.166950  5.145125  11.966875  16.724538         19.152  147.217300
# 2  27.970713  7.459813   2.474852   5.142212          0.000  386.777895
# 3  19.815070  3.004800  13.549490   3.465458          0.000  100.355500
# 4  29.506350  7.253650   4.189283   5.774230          0.000  641.658069
#
#   Healthy HealthyLabel
# 0  [1, 0]      healthy
# 1  [1, 0]      healthy
# ...

# %%
# Assign X (data) and y (target)

X = testdata.drop(['Healthy',"HealthyLabel"], axis=1)
y = testdata["HealthyLabel"]
print(X.shape, y.shape)
# Out:
# (1849, 12) (1849,)

# %%
#split data into test and tain
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\david\Anaconda3\envs\PythonWebMongo\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.841991341991342
# Testing Data Score: 0.8596112311015118

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['unhealthy' 'healthy' 'healthy' 'unhealthy' 'healthy' 'healthy' 'healthy'
#  'unhealthy' 'unhealthy' 'healthy']
# First 10 Actual labels: ['unhealthy', 'healthy', 'healthy', 'unhealthy', 'healthy', 'healthy', 'healthy', 'unhealthy', 'unhealthy', 'unhealthy']

# %%
newrecipe = [[2487.4871677698566, 115.0143722589952, 36.711355579281225, 0.30856, 49.78661254561268, 20.023414075971647, 258.46717506187764, 14.218, 45.58577014101037, 99.37450174388997, 198.76893064748802, 3797.5723608635963]]
newrecipe2 = [X.iloc[1848]]
newpredict = classifier.predict(newrecipe)

print(newpredict)
# Out:
# ['unhealthy']

# %%
testdata.tail()
# Out:
#        Calories/s      Fat/s  Sat_Fat/s  Trans_Fat/s  Mono_Fat/s  Poly_Fat/s  \
# 1844   885.555968  53.018457  21.638624     0.465476   22.651813    3.703198
# 1845  1199.745198  52.064223  21.695331     0.055055   20.987810    6.193580
# 1846   575.813376  29.716701  17.255565     0.668482    7.652011    1.418145
# 1847   223.868965   8.640837   3.993991     0.006804    2.284186    1.262668
# 1848   453.053030  29.118689  15.106494     0.082530    8.686451    1.648327
#
#          Carbs/s   Fiber/s   Sugars/s  Protein/s  Cholesterol/s     Sodium/s  \
# 1844   41.120828  3.092770   5.914407  44.262083     175.963054   668.928226
# 1845  132.531893  9.903497  10.157808  48.270264      99.680000  2843.324175
# 1846   48.349441  2.459127   2.626872  28.114553      85.888248   792.458453
# 1847   26.627345  5.083299  11.188909  10.390328      22.906415   861.444700
# 1848   34.804224  2.571149   5.466125  14.342200      82.124489   363.201978
#
#      Healthy HealthyLabel
# ...

# %%
from sklearn_export import Export

# %%
# Save using sklearn_export
export = Export(classifier)
export.to_json()

# %%
# Create function in JavaScript, resource for Logistic Regression equation: p = e^(intercept + B1X1 + B2X2 + B3X3...)/1 + e^(intercept + B1X1 + B2X2 + B3X3...)
# https://machinelearningmastery.com/logistic-regression-for-machine-learning/
