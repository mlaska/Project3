# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
#import data
data = pd.read_csv("../data/ModelData_3.csv")
data.head()
# Out:
#    Servings/s  Calories/s      Fat/s  Sat_Fat/s  Trans_Fat/s  Mono_Fat/s  \
# 0         1.0  180.765324   9.996749   0.881106     0.002681    5.909383
# 1         1.0  775.941625  56.405072  15.714442     0.000000   31.153127
# 2         1.0  139.940343   4.085529   1.955598     0.116622    1.306040
# 3         1.0  444.175500  29.082133   2.437576     0.000000    2.585873
# 4         1.0  675.905833   9.455200   5.855028     0.000000    2.016633
#
#    Poly_Fat/s     Carbs/s    Fiber/s   Sugars/s  ...  Folate_eq/s  \
# 0    2.715325   18.898969   5.400785   3.203595  ...    34.703941
# 1    7.137887   39.867356   8.835737   5.574340  ...   270.598875
# 2    0.472402   20.672074   3.724584  12.501256  ...    30.424638
# 3   10.275212   39.679250   5.534250  19.483342  ...    42.163333
# 4    0.828498  116.167633  13.014667  13.465767  ...   485.213333
#
#    Folate_food/s     B12/s  Vit_D/s   Vit_E/s    Vit_K/s     Water/s  Healthy  \
# 0      34.703941  0.000000     0.00  5.525899  10.415717   89.061403        1
# 1     270.598875  1.028300     0.00  3.822665  88.537138  167.266723        1
# 2      30.424638  0.006035     2.13  1.274294  15.303048  134.552731        1
# 3      42.163333  0.000000     0.00  4.994358   1.991167   77.359608        1
# 4     487.568333  0.633750     6.00  0.738625  13.453000  141.845975        1
#
#    HealthyLabel                                             Recipe
# 0       healthy                            2 Minute Pumpkin Quinoa
# 1       healthy  3-Ingredient Sausage Dinner With Lentils and F...
# 2       healthy                                     Almond Carrots
# 3       healthy                   Almond, peach and quinoa crumble
# 4       healthy                    Apple flavored lentils and rice
#
# [5 rows x 35 columns]

# %%
#
testdata = data[['Calories/s', 'Fat/s', 'Sat_Fat/s', 'Trans_Fat/s', 'Mono_Fat/s', 'Poly_Fat/s',
                'Carbs/s', 'Fiber/s', 'Sugars/s','Protein/s', 'Cholesterol/s', 'Sodium/s', 'Healthy', 'HealthyLabel']].copy()
testdata.head()
# Out:
#    Calories/s      Fat/s  Sat_Fat/s  Trans_Fat/s  Mono_Fat/s  Poly_Fat/s  \
# 0  180.765324   9.996749   0.881106     0.002681    5.909383    2.715325
# 1  775.941625  56.405072  15.714442     0.000000   31.153127    7.137887
# 2  139.940343   4.085529   1.955598     0.116622    1.306040    0.472402
# 3  444.175500  29.082133   2.437576     0.000000    2.585873   10.275212
# 4  675.905833   9.455200   5.855028     0.000000    2.016633    0.828498
#
#       Carbs/s    Fiber/s   Sugars/s  Protein/s  Cholesterol/s    Sodium/s  \
# 0   18.898969   5.400785   3.203595   6.528392         0.0000    6.553975
# 1   39.867356   8.835737   5.574340  29.405571        85.8800  890.212500
# 2   20.672074   3.724584  12.501256   1.764834         7.6325  384.135792
# 3   39.679250   5.534250  19.483342   9.969008         0.0000    3.963700
# 4  116.167633  13.014667  13.465767  33.013908        33.3750  354.855833
#
#    Healthy HealthyLabel
# 0        1      healthy
# 1        1      healthy
# 2        1      healthy
# 3        1      healthy
# 4        1      healthy

# %%
# Assign X (data) and y (target)

X = testdata.drop(['Healthy',"HealthyLabel"], axis=1)
y = testdata["Healthy"]
print(X.shape, y.shape)
# Out:
# (1649, 12) (1649,)

# %%
#split data into test and tain
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\david\Anaconda3\envs\PythonWebMongo\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8147249190938511
# Testing Data Score: 0.8353510895883777

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   [0 1 1 1 1 1 1 0 1 0]
# First 10 Actual labels: [0, 0, 0, 1, 1, 1, 1, 0, 1, 0]

# %%
newrecipe = [[2487.4871677698566, 115.0143722589952, 36.711355579281225, 0.30856, 49.78661254561268, 20.023414075971647, 258.46717506187764, 14.218, 45.58577014101037, 99.37450174388997, 198.76893064748802, 3797.5723608635963]]
newrecipe2 = [X.iloc[1548]]
newpredict = classifier.predict(newrecipe)

print(newpredict)
# Out:
# [0]

# %%
testdata.tail()
# Out:
#        Calories/s      Fat/s  Sat_Fat/s  Trans_Fat/s  Mono_Fat/s  Poly_Fat/s  \
# 1644   885.555968  53.018457  21.638624     0.465476   22.651813    3.703198
# 1645  1199.745198  52.064223  21.695331     0.055055   20.987810    6.193580
# 1646   575.813376  29.716701  17.255565     0.668482    7.652011    1.418145
# 1647   223.868965   8.640837   3.993991     0.006804    2.284186    1.262668
# 1648   453.053030  29.118689  15.106494     0.082530    8.686451    1.648327
#
#          Carbs/s   Fiber/s   Sugars/s  Protein/s  Cholesterol/s     Sodium/s  \
# 1644   41.120828  3.092770   5.914407  44.262083     175.963054   668.928226
# 1645  132.531893  9.903497  10.157808  48.270264      99.680000  2843.324175
# 1646   48.349441  2.459127   2.626872  28.114553      85.888248   792.458453
# 1647   26.627345  5.083299  11.188909  10.390328      22.906415   861.444700
# 1648   34.804224  2.571149   5.466125  14.342200      82.124489   363.201978
#
#       Healthy HealthyLabel
# 1644        0    unhealthy
# 1645        0    unhealthy
# 1646        0    unhealthy
# 1647        0    unhealthy
# 1648        0    unhealthy

# %%
from sklearn_export import Export

# %%
# Save using sklearn_export
export = Export(classifier)
export.to_json()

# %%
# Create function in JavaScript, resource for Logistic Regression equation: p = e^(intercept + B1X1 + B2X2 + B3X3...)/1 + e^(intercept + B1X1 + B2X2 + B3X3...)
# https://machinelearningmastery.com/logistic-regression-for-machine-learning/
